# %% [markdown]
# # Stage: CrossRef
#
# Runs `process_folder` for one issue under `Input/`.

# %%
from pathlib import Path
import os
import sys

def resolve_project_root() -> Path:
    cwd = Path.cwd().resolve()
    if (cwd / "Input").is_dir():
        return cwd
    if (cwd.parent / "Input").is_dir():
        return cwd.parent
    return cwd

PROJECT_ROOT = resolve_project_root()
repo_root_str = str(PROJECT_ROOT)
if repo_root_str not in sys.path:
    sys.path.insert(0, repo_root_str)
os.chdir(PROJECT_ROOT)

# %%
FOLDER = 'ajil0120no1'

from CrossRef.extract import process_folder

inp = PROJECT_ROOT / 'Input' / FOLDER
process_folder(FOLDER, str(inp))
